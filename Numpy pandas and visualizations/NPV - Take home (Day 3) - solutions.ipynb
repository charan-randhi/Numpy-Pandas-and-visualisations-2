# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
import numpy as np
import pandas as pd 
from pandas import DataFrame as df

# %%
sales=df([['A', 'Mumbai',40000], ['B','Pune',45000], ['A','Hyderabad',50000],['C','Mumbai',90000],['D','Pune',89000],['A','Delhi',87000],['D','Hyderabad',85000],['A','Pune',78000],['C','Mumbai',89000],['B','Pune',70000]],columns=['Store','Location','Sales'])
sales
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  50000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
pd.crosstab(sales['Store'],sales['Location'],values=sales['Sales'],aggfunc=min)
# Out:
# Location    Delhi  Hyderabad   Mumbai     Pune
# Store
# A         87000.0    50000.0  40000.0  78000.0
# B             NaN        NaN      NaN  45000.0
# C             NaN        NaN  89000.0      NaN
# D             NaN    85000.0      NaN  89000.0

# %%
pd.pivot_table(sales,index=['Store','Location'],aggfunc=max)
# Out:
#                  Sales
# Store Location
# A     Delhi      87000
#       Hyderabad  50000
#       Mumbai     40000
#       Pune       78000
# B     Pune       70000
# C     Mumbai     90000
# D     Hyderabad  85000
#       Pune       89000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
b=df({'Name':['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachine'],'Salary':[3400,3000,1600,3000,3000,3000,4000,3000],'city':['Sydney','Chicago','Newyork','Chicago','Chicago','Texas','London','Chicago']})
b[b.duplicated(['Name'])]
# Out:
#      Name  Salary     city
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago
# 5  Robert    3000    Texas
# 6    Aadi    4000   London

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
game=df({'days':['Mon','Tues','Wed','Thurs','Fri'],'tournament':['football','cricket','football','football','cricket']})
df(np.where(game=='football','cricket',game))
# Out:
#        0        1
# 0    Mon  cricket
# 1   Tues  cricket
# 2    Wed  cricket
# 3  Thurs  cricket
# 4    Fri  cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
d=pd.DataFrame({'month':['jan','feb','mar','apr','may','june','july','aug','sep','oct','nov','dec'],'sales':[22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,56000,60000],'seasons':['winter','winter','spring','spring','spring','summer','summer','summer','fall','fall','fall','winter']})
d.describe()
# Out:
#               sales
# count     12.000000
# mean   48166.666667
# std    19385.249000
# min    22000.000000
# 25%    28500.000000
# 50%    56000.000000
# 75%    61750.000000
# max    78000.000000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
e=df({'name':['emma','mia','sophia','james','john'],'maths':[56,78,78,67,88],'science':[89,87,78,89,78],'english':[89,89,76,78,87]})
e['age']=[20,21,19,20,22]
e
# Out:
#      name  maths  science  english  age
# 0    emma     56       89       89   20
# 1     mia     78       87       89   21
# 2  sophia     78       78       76   19
# 3   james     67       89       78   20
# 4    john     88       78       87   22

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
f=df({'stud_id':[101,102,103,104,105],'name':['alex','amy','allen','alice','james'],'MA(Hons)':['history','english','geography','german','history']})
g=df({'stud_id':[101,102,103,104,105],'res_city':['delhi','mumbai','delhi','chennai','hyderabad'],'MA(Hons)':['english','history','fine arts','german','history']})
g
# Out:
#    stud_id   res_city   MA(Hons)
# 0      101      delhi    english
# 1      102     mumbai    history
# 2      103      delhi  fine arts
# 3      104    chennai     german
# 4      105  hyderabad    history

# %%
f
# Out:
#    stud_id   name   MA(Hons)
# 0      101   alex    history
# 1      102    amy    english
# 2      103  allen  geography
# 3      104  alice     german
# 4      105  james    history

# %%
pd.merge(f,g,on=['MA(Hons)','stud_id'],how='right')
# Out:
#    stud_id   name   MA(Hons)   res_city
# 0      104  alice     german    chennai
# 1      105  james    history  hyderabad
# 2      101    NaN    english      delhi
# 3      102    NaN    history     mumbai
# 4      103    NaN  fine arts      delhi

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
pd.merge(f,g,on=['MA(Hons)','stud_id'],how='inner')
# Out:
#    stud_id   name MA(Hons)   res_city
# 0      104  alice   german    chennai
# 1      105  james  history  hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
f1=df({'stud_id':[101,102,103,104,105],'name':['alex','amy','allen','alice','james']})
f1
# Out:
#    stud_id   name
# 0      101   alex
# 1      102    amy
# 2      103  allen
# 3      104  alice
# 4      105  james

# %%
g1=df({'res_city':['delhi','mumbai','delhi','chennai','hyderabad'],'MA(Hons)':['english','history','fine arts','german','history']})
g1
# Out:
#     res_city   MA(Hons)
# 0      delhi    english
# 1     mumbai    history
# 2      delhi  fine arts
# 3    chennai     german
# 4  hyderabad    history

# %%
g2=pd.concat([f1,g1],axis=1)
g2
# Out:
#    stud_id   name   res_city   MA(Hons)
# 0      101   alex      delhi    english
# 1      102    amy     mumbai    history
# 2      103  allen      delhi  fine arts
# 3      104  alice    chennai     german
# 4      105  james  hyderabad    history

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Alex</td>
# <td>Maths</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Amy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Allen</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Alice</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Ayoung</td>
# <td>History</td>
# </tr>
#
# </table><br>
#
#
#
# <table>
# <tr>
# <th>ID</th>
# <th>Name</th>
# <th>Subject</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Billy</td>
# <td>English</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Brian</td>
# <td>Science</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Bran</td>
# <td>Social Science</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Bryce</td>
# <td>German</td>
# </tr>
# <td>105</td>
# <td>Betty</td>
# <td>History</td>
# </tr>
#
# </table>

# %%
d.groupby(['seasons']).agg('mean')
# Out:
#                 sales
# seasons
# fall     56000.000000
# spring   29666.666667
# summer   70666.666667
# winter   36333.333333

# %%
d.groupby(['seasons']).agg(min)
# Out:
#         month  sales
# seasons
# fall      nov  56000
# spring    apr  25000
# summer    aug  67000
# winter    dec  22000

# %%
d.groupby(['seasons']).agg(max)
# Out:
#         month  sales
# seasons
# fall      sep  56000
# spring    may  35000
# summer   june  78000
# winter    jan  60000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %%
dup=df({'x':[1,2,3,1,2,3,2,2],'y':[2,2,1,2,2,4,2,2],'z':[5,6,2,6,1,6,2,8]})
dup
# Out:
#    x  y  z
# 0  1  2  5
# 1  2  2  6
# 2  3  1  2
# 3  1  2  6
# 4  2  2  1
# 5  3  4  6
# 6  2  2  2
# 7  2  2  8

# %%
dup.drop_duplicates(['x','y'],keep='first')
# Out:
#    x  y  z
# 0  1  2  5
# 1  2  2  6
# 2  3  1  2
# 5  3  4  6

# %%
dup[dup.duplicated(['x','y'],keep='first')]
# Out:
#    x  y  z
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8
